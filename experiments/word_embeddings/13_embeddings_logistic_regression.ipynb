# %%
import os
import sys

os.chdir("/Users/karima/Ironhack-challenges/fake-news-nlp-classification")
sys.path.append(os.getcwd())

print(os.getcwd())
# Out:
# /Users/karima/Ironhack-challenges/fake-news-nlp-classification

# %%
# %pip install gensim

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from src.data_loader import load_data, prepare_features_and_labels, split_data
from src.preprocessing import preprocess_data
from src.feature_extraction import load_glove_model, create_glove_tfidf_weighted_embedding_features
from src.evaluator import evaluate_model, save_confusion_matrix, save_metrics_plot
from src.experiment_tracker import save_experiment_result
from src.model_manager import save_model, save_vectorizer
from src.config import MODELS_DIR

# %%
# Class constants
MODEL_ID = "exp_13"
MODEL_NAME = "Logistic Regression + Average GloVe Embeddings"
FEATURES = "Average GloVe Word Embeddings"
PREPROCESSING = "Lowercase + HTML removal + stopword removal + lemmatization"
ALGORITHM = "Logistic Regression"
NOTES = "Uses pre-trained GloVe vectors averaged across each document."
MODEL_PATH = MODELS_DIR / "embeddings_logistic_regression.pkl"

# %%
# Load the dataset
data = load_data()

# %%
# Extract features X and labels y
X, y = prepare_features_and_labels(data)

# %%
# Split the data into 80% train and 20% test
X_train, X_test, y_train, y_test = split_data(X, y)

# %%
# data cleaning, tokenizationa and lemmatization
X_train_clean = preprocess_data(X_train)
X_test_clean = preprocess_data(X_test)

# %%
glove_model = load_glove_model()

# %%
#  Create glove tf-idf weighted embeddings features
X_train_embeddings, X_test_embeddings, tfidf_vectorizer = (
    create_glove_tfidf_weighted_embedding_features(
        X_train_clean,
        X_test_clean,
        glove_model
    )
)

# %%
# Train the model
model = LogisticRegression(
    max_iter=1000,
    random_state=42
)
model.fit(X_train_embeddings, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
# evaluate the model
metrics, predictions = evaluate_model(
    model,
    X_test_embeddings,
    y_test
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      3989
#            1       0.92      0.93      0.93      4000
#
#     accuracy                           0.93      7989
#    macro avg       0.93      0.93      0.93      7989
# weighted avg       0.93      0.93      0.93      7989

# %%
# Save the model and the vectorizer
model_path = save_model(
    model,
    "embeddings_logistic_regression.pkl"
)

save_vectorizer(
    tfidf_vectorizer,
    "embeddings_logistic_regression_vectorizer.pkl"
)
# Out:
# Model saved to: /Users/karima/Ironhack-challenges/fake-news-nlp-classification/models/embeddings_logistic_regression.pkl
# Vectorizer saved to: /Users/karima/Ironhack-challenges/fake-news-nlp-classification/models/embeddings_logistic_regression_vectorizer.pkl
# '/Users/karima/Ironhack-challenges/fake-news-nlp-classification/models/embeddings_logistic_regression_vectorizer.pkl'

# %%
# Save and show metrics plot
metrics_plot_path = save_metrics_plot(
    metrics,
    "exp_13_embeddings_logistic_regression"
)

# %%
# Save and show confusion matrix
confusion_matrix_path = save_confusion_matrix(
    y_test,
    predictions,
    "13_bembeddings_logistic_regression"
)

# %%
# Train accuracy
train_predictions = model.predict(X_train_embeddings)
train_accuracy = accuracy_score(y_train, train_predictions)

# %%
# Save experiment result
experiment = {
    "model_id": MODEL_ID,
    "model_name": MODEL_NAME,
    "features": FEATURES,
    "preprocessing": PREPROCESSING,
    "algorithm": ALGORITHM,
    "train_accuracy": train_accuracy,
    "test_accuracy": metrics["test_accuracy"],
    "precision": metrics["precision"],
    "recall": metrics["recall"],
    "f1_score": metrics["f1_score"],
    "notes": NOTES,
    "model_path": MODEL_PATH,
}

tracking = save_experiment_result(**experiment)

tracking.tail()
# Out:
#   model_id                                      model_name  \
# 3   exp_02                      Naive Bayes + Bag of Words
# 4   exp_03                    Random Forest + Bag of Words
# 5   exp_04                              SVM + Bag of Words
# 6   exp_13  Logistic Regression + Average GloVe Embeddings
# 7   exp_13  Logistic Regression + Average GloVe Embeddings
#
#                         features  \
# 3                   Bag of Words
# 4                   Bag of Words
# 5                   Bag of Words
# 6  Average GloVe Word Embeddings
# 7  Average GloVe Word Embeddings
#
#                                        preprocessing                algorithm  \
# 3  Lowercase + HTML removal + stopword removal + ...  Multinomial Naive Bayes
# 4  Lowercase + HTML removal + stopword removal + ...            Random Forest
# 5  Lowercase + HTML removal + stopword removal + ...               Linear SVM
# 6  Lowercase + HTML removal + stopword removal + ...      Logistic Regression
# 7  Lowercase + HTML removal + stopword removal + ...      Logistic Regression
#
#    train_accuracy  test_accuracy  precision   recall  f1_score  \
# 3        0.959785       0.948429   0.949399  0.94750  0.948448
# 4        1.000000       0.990487   0.989277  0.99175  0.990512
# 5        1.000000       0.994743   0.994997  0.99450  0.994749
# 6        0.930992       0.927275   0.923248  0.93225  0.927727
# 7        0.933152       0.926399   0.922696  0.93100  0.926829
#
#                                                notes  \
# 3     Naive Bayes model using Bag of Words features.
# 4   Random Forest model using Bag of Words features.
# 5      Linear SVM model using Bag of Words features.
# 6  Uses pre-trained GloVe vectors averaged across...
# 7  Uses pre-trained GloVe vectors averaged across...
#
#                                           model_path
# 3  /Users/karima/Ironhack-challenges/fake-news-nl...
# 4  /Users/karima/Ironhack-challenges/fake-news-nl...
# 5  /Users/karima/Ironhack-challenges/fake-news-nl...
# 6  /Users/karima/Ironhack-challenges/fake-news-nl...
# 7  /Users/karima/Ironhack-challenges/fake-news-nl...
