# %%
import os
import sys

os.chdir("/Users/karima/Ironhack-challenges/fake-news-nlp-classification")
sys.path.append(os.getcwd())

print(os.getcwd())
# Out:
# /Users/karima/Ironhack-challenges/fake-news-nlp-classification

# %%
# Core imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_data, prepare_features_and_labels, split_data

# %%
df = load_data()
print(df.shape)
#df = df.head(1000)
df
# Out:
# (39942, 5)
#        label                                              title  \
# 0          1  As U.S. budget fight looms, Republicans flip t...
# 1          1  U.S. military to accept transgender recruits o...
# 2          1  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3          1  FBI Russia probe helped by Australian diplomat...
# 4          1  Trump wants Postal Service to charge 'much mor...
# ...      ...                                                ...
# 39937      0  THIS IS NOT A JOKE! Soros-Linked Group Has Pla...
# 39938      0  THE SMARTEST WOMAN In Politics: “How Trump Can...
# 39939      0  BREAKING! SHOCKING VIDEO FROM CHARLOTTE RIOTS:...
# 39940      0  BREAKING! Charlotte News Station Reports Cops ...
# 39941      0  BIG MISTAKE! HILLARY JUST Proved To America Sh...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 39937  The Left has been organizing for decades, and ...     left-news
# 39938  Monica Crowley offers some of the most brillia...     left-news
# 39939  Protest underway in Charlotte:  Things got com...     left-news
# 39940  Local Charlotte, NC news station WSOCTV is rep...     left-news
# 39941  Dividing America will be Obama s legacy. Hilla...     left-news
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 39937        Sep 22, 2016
# 39938        Sep 22, 2016
# 39939        Sep 21, 2016
# 39940        Sep 21, 2016
# 39941        Sep 21, 2016
#
# [39942 rows x 5 columns]

# %% [markdown]
# ## 1. Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39942 entries, 0 to 39941
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    39942 non-null  int64
#  1   title    39942 non-null  str
#  2   text     39942 non-null  str
#  3   subject  39942 non-null  str
#  4   date     39942 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 1.5 MB

# %%
print("Shape:", df.shape)
print("\nMissing values: ", df.isnull().sum().sum())
df.info()
# Out:
# Shape: (39942, 5)
#
# Missing values:  0
# <class 'pandas.DataFrame'>
# RangeIndex: 39942 entries, 0 to 39941
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    39942 non-null  int64
#  1   title    39942 non-null  str
#  2   text     39942 non-null  str
#  3   subject  39942 non-null  str
#  4   date     39942 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 1.5 MB

# %%
# --- Label distribution ---
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

sns.countplot(x='label', data=df, ax=ax[0])
ax[0].set_title('Label Distribution (count)')

df['label'].value_counts(normalize=True).plot.pie(
    autopct='%1.1f%%', ax=ax[1], ylabel=''
)
ax[1].set_title('Label Distribution (%)')

plt.tight_layout()
plt.show()

# %%
# --- Categorical column distribution (e.g. subject) ---
plt.figure(figsize=(6, 4))
sns.countplot(x='subject', data=df, order=df['subject'].value_counts().index)
plt.title('Subject Distribution')
plt.show()

# Label distribution across categories — useful to spot imbalance/bias per group
plt.figure(figsize=(6, 4))
sns.countplot(x='subject', hue='label', data=df)
plt.title('Label Distribution by subject')
plt.show()

# %%
df['subject'].value_counts()
# Out:
# subject
# politicsNews       11272
# News                9050
# worldnews           8727
# politics            6841
# left-news           2482
# Government News     1570
# Name: count, dtype: int64

# %%
# --- Text length distribution (quick sanity check per text column) ---
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

df['title'].str.split().apply(len).plot.hist(ax=ax[0], bins=10)
ax[0].set_title('Title Word Count')

df['text'].str.split().apply(len).plot.hist(ax=ax[1], bins=10)
ax[1].set_title('Text Word Count')

plt.tight_layout()
plt.show()

# %%
sns.countplot(x='subject', data=df)
pd.crosstab(df['subject'], df['label'])
# Out:
# label               0      1
# subject
# Government News  1570      0
# News             9050      0
# left-news        2482      0
# politics         6841      0
# politicsNews        0  11272
# worldnews           0   8727

# %%
#--- Date distribution ---
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df.groupby(df['date'].dt.to_period('M'))['label'].value_counts().unstack().plot()
# Out:
# <Axes: xlabel='date'>

# %%
#--- Text length per label ---
df['text_len'] = df['text'].str.split().apply(len)
sns.histplot(data=df, x='text_len', hue='label', bins=50)
# Out:
# <Axes: xlabel='text_len', ylabel='Count'>

# %%
df['date'].value_counts()
# Out:
# date
# 2017-12-20    182
# 2017-12-06    166
# 2017-11-30    162
# 2017-11-09    158
# 2017-10-13    155
#              ...
# 2016-05-30      1
# 2016-05-28      1
# 2016-05-22      1
# 2016-05-14      1
# 2016-01-24      1
# Name: count, Length: 716, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Convert string date to datetime ---
# errors='coerce' turns unparseable dates into NaT instead of raising an error
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Check how many dates failed to parse (worth inspecting these rows)
print("Unparseable dates:", df['date'].isna().sum())

# Optional: extract useful sub-features
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['year_month'] = df['date'].dt.to_period('M')

# --- 2. Plot date distribution by label ---

# A) Histogram of raw dates, split by label
plt.figure(figsize=(12, 5))
sns.histplot(data=df, x='date', hue='label', bins=50, multiple='stack')
plt.title('Distribution of Articles Over Time by Label')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# B) Monthly counts per label (often clearer than raw daily histogram)
monthly_counts = df.groupby(['year_month', 'label']).size().unstack(fill_value=0)

monthly_counts.plot(kind='line', figsize=(12, 5), marker='o')
plt.title('Monthly Article Count by Label')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.legend(title='Label', labels=['Fake (0)', 'Real (1)'])
plt.tight_layout()
plt.show()

# C) Yearly distribution (simpler view, good for spotting date-based leakage)
plt.figure(figsize=(8, 5))
sns.countplot(x='year', hue='label', data=df)
plt.title('Article Count by Year and Label')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Unparseable dates: 19943

# %%
df[df['date'].isna()]['label'].value_counts()
# Out:
# label
# 0    19943
# Name: count, dtype: int64

# %% [markdown]
# # comments
# - Drop subject
#   - clear distinction between the labels. Some subjects clearly predict the label. so there is data leak
# - Drop date
#   - not relavent
#   - some dates not convertable
#   - keep empty text for now ---> later come to it

# %%
df[df[['title', 'text']].duplicated()]
# Out:
#        label                                              title  \
# 445        1  Senate tax bill stalls on deficit-focused 'tri...
# 778        1  Trump warns 'rogue regime' North Korea of grav...
# 892        1  Republicans unveil tax cut bill, but the hard ...
# 896        1  Trump taps Fed centrist Powell to lead U.S. ce...
# 974        1  Two ex-Trump aides charged in Russia probe, th...
# ...      ...                                                ...
# 39936      0  YIKES! Tomi Lahren DEMOLISHES Hillary: “How Da...
# 39937      0  THIS IS NOT A JOKE! Soros-Linked Group Has Pla...
# 39938      0  THE SMARTEST WOMAN In Politics: “How Trump Can...
# 39940      0  BREAKING! Charlotte News Station Reports Cops ...
# 39941      0  BIG MISTAKE! HILLARY JUST Proved To America Sh...
#
#                                                     text       subject  \
# 445    WASHINGTON (Reuters) - The U.S. Senate on Thur...  politicsNews
# 778    BEIJING (Reuters) - U.S. President Donald Trum...  politicsNews
# 892    WASHINGTON (Reuters) - U.S. House of Represent...  politicsNews
# 896    WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 974    WASHINGTON (Reuters) - Federal investigators p...  politicsNews
# ...                                                  ...           ...
# 39936  Wow! Bravo Tomi! You really nailed it this tim...     left-news
# 39937  The Left has been organizing for decades, and ...     left-news
# 39938  Monica Crowley offers some of the most brillia...     left-news
# 39940  Local Charlotte, NC news station WSOCTV is rep...     left-news
# 39941  Dividing America will be Obama s legacy. Hilla...     left-news
#
#             date  text_len    year  month year_month
# 445   2017-11-30       995  2017.0   11.0    2017-11
# 778   2017-11-08      1134  2017.0   11.0    2017-11
# 892   2017-11-02      1060  2017.0   11.0    2017-11
# 896   2017-11-02       909  2017.0   11.0    2017-11
# 974   2017-10-30       969  2017.0   10.0    2017-10
# ...          ...       ...     ...    ...        ...
# 39936        NaT        55     NaN    NaN        NaT
# 39937        NaT       841     NaN    NaN        NaT
# 39938        NaT       791     NaN    NaN        NaT
# 39940        NaT       380     NaN    NaN        NaT
# 39941        NaT       171     NaN    NaN        NaT
#
# [3513 rows x 9 columns]

# %%
#--- Text length per label ---
df['text_len'] = df['text'].str.split().apply(len)
df['title_len'] = df['title'].str.split().apply(len)

# %%
df.text_len.value_counts()
# Out:
# text_len
# 0       610
# 403     147
# 402     140
# 406     131
# 405     126
#        ...
# 2470      1
# 1383      1
# 4149      1
# 1202      1
# 1336      1
# Name: count, Length: 1454, dtype: int64

# %%
df[df['text_len'] == 0]#['label'].value_counts()
# Out:
#        label                                              title text  \
# 8970       1                     Graphic: Supreme Court roundup
# 30922      0  TAKE OUR POLL: Who Do You Think President Trum...
# 31040      0  Joe Scarborough BERATES Mika Brzezinski Over “...
# 31189      0  WATCH TUCKER CARLSON Scorch Sanctuary City May...
# 31224      0  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...
# ...      ...                                                ...  ...
# 39862      0  FUNNY! MSNBC ANCHOR ASKS Millennial Women If T...
# 39866      0  UNREAL! OBAMA BLAMES SYRIAN CIVIL WAR ON CLIMA...
# 39894      0  WHAT WAS HE THINKING? DISHEVELED OBAMA YELLS F...
# 39898      0  MUSLIM WOMAN BUSTED Buying Soda With Food Stam...
# 39934      0  THIS VIDEO WILL DESTROY “Black Lives Matter”…S...
#
#             subject       date  text_len    year  month year_month  title_len
# 8970   politicsNews 2016-06-16         0  2016.0    6.0    2016-06          4
# 30922      politics        NaT         0     NaN    NaN        NaT         15
# 31040      politics        NaT         0     NaN    NaN        NaT         19
# 31189      politics        NaT         0     NaN    NaN        NaT         13
# 31224      politics        NaT         0     NaN    NaN        NaT         13
# ...             ...        ...       ...     ...    ...        ...        ...
# 39862     left-news        NaT         0     NaN    NaN        NaT         13
# 39866     left-news        NaT         0     NaN    NaN        NaT         15
# 39894     left-news        NaT         0     NaN    NaN        NaT         17
# 39898     left-news        NaT         0     NaN    NaN        NaT         17
# 39934     left-news        NaT         0     NaN    NaN        NaT          9
#
# [610 rows x 10 columns]
